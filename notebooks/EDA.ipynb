# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Config display
import sys
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from skimpy import skim
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.discovery import all_displays
# from tune_sklearn import TuneGridSearchCV
# from sklearn.tree import export_graphviz

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.float_format", lambda x: "%.3f" % x)
pd.set_option("display.width", 500)

# Config sys path
if ('../' not in sys.path):
    sys.path.append('../')
    
# Import library
from fraud import *
from sklearn.model_selection import train_test_split

# Set seed
seed = 4263

# %%
# Load dataset 
load_path = "../data/processed/"
df1 = load(load_path)
df2 = load_new(load_path)

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(df1, x="phishing", y="length_url", hue="phishing", width=.6, palette="vlag", showfliers=False)
plt.title("Box Plot - Length of URL (Dataset 1)")
plt.show()

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(df2, x="phishing", y="length_url", hue="phishing", width=.6, palette="vlag", showfliers=False)
plt.title("Box Plot - Length of URL (Dataset 2)")
plt.show()

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(df1, x="phishing", y="qty_dot_url", hue="phishing", width=.6, palette="vlag", showfliers=False)
plt.title("Box Plot - Quantity of Dot in URL (Dataset 1)")
plt.show()

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(df2, x="phishing", y="qty_dot_url", hue="phishing", width=.6, palette="vlag", showfliers=False)
plt.title("Box Plot - Quantity of Dot in URL (Dataset 2)")
plt.show()

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(df1, x="phishing", y="qty_slash_directory", hue="phishing", width=.6, palette="vlag", showfliers=False)
plt.title("Box Plot - Quantity of Slash in Directory (Dataset 1)")
plt.show()

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(df2, x="phishing", y="qty_slash_directory", hue="phishing", width=.6, palette="vlag", showfliers=False)
plt.title("Box Plot - Quantity of Slash in Directory (Dataset 2)")
plt.show()

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(df1, x="phishing", y="qty_vowels_domain", hue="phishing", width=.6, palette="vlag", showfliers=False)
plt.title("Box Plot - Quantity of Vowels in Domain (Dataset 1)")
plt.show()

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(df2, x="phishing", y="qty_vowels_domain", hue="phishing", width=.6, palette="vlag", showfliers=False)
plt.title("Box Plot - Quantity of Vowels in Domain (Dataset 2)")
plt.show()
